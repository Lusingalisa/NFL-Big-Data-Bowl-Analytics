# %% [markdown]
# # importing the necessary libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
track = pd.read_csv("114239_nfl_competition_files_published_analytics_final/train/input_2023_w01.csv")
track.head()
# Out:
#       game_id  play_id  player_to_predict  nfl_id  frame_id play_direction  \
# 0  2023090700      101              False   54527         1          right
# 1  2023090700      101              False   54527         2          right
# 2  2023090700      101              False   54527         3          right
# 3  2023090700      101              False   54527         4          right
# 4  2023090700      101              False   54527         5          right
#
#    absolute_yardline_number player_name player_height  player_weight  ...  \
# 0                        42  Bryan Cook           6-1            210  ...
# 1                        42  Bryan Cook           6-1            210  ...
# 2                        42  Bryan Cook           6-1            210  ...
# 3                        42  Bryan Cook           6-1            210  ...
# 4                        42  Bryan Cook           6-1            210  ...
#
#           player_role      x      y     s     a     dir       o  \
# ...

# %%
track.columns
# Out:
# Index(['game_id', 'play_id', 'player_to_predict', 'nfl_id', 'frame_id',
#        'play_direction', 'absolute_yardline_number', 'player_name',
#        'player_height', 'player_weight', 'player_birth_date',
#        'player_position', 'player_side', 'player_role', 'x', 'y', 's', 'a',
#        'dir', 'o', 'num_frames_output', 'ball_land_x', 'ball_land_y'],
#       dtype='object')

# %%
track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285714 entries, 0 to 285713
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   game_id                   285714 non-null  int64
#  1   play_id                   285714 non-null  int64
#  2   player_to_predict         285714 non-null  bool
#  3   nfl_id                    285714 non-null  int64
#  4   frame_id                  285714 non-null  int64
#  5   play_direction            285714 non-null  object
#  6   absolute_yardline_number  285714 non-null  int64
#  7   player_name               285714 non-null  object
#  8   player_height             285714 non-null  object
#  9   player_weight             285714 non-null  int64
#  10  player_birth_date         285714 non-null  object
#  11  player_position           285714 non-null  object
#  12  player_side               285714 non-null  object
# ...

# %%
# checking for missing and duplicate values
track.duplicated().sum()
# Out:
# 0

# %%
track.isnull().sum()
# Out:
# game_id                     0
# play_id                     0
# player_to_predict           0
# nfl_id                      0
# frame_id                    0
# play_direction              0
# absolute_yardline_number    0
# player_name                 0
# player_height               0
# player_weight               0
# player_birth_date           0
# player_position             0
# player_side                 0
# player_role                 0
# x                           0
# y                           0
# s                           0
# a                           0
# dir                         0
# o                           0
# num_frames_output           0
# ball_land_x                 0
# ball_land_y                 0
# dtype: int64

# %%
track.head()
# Out:
#       game_id  play_id  player_to_predict  nfl_id  frame_id play_direction  \
# 0  2023090700      101              False   54527         1          right
# 1  2023090700      101              False   54527         2          right
# 2  2023090700      101              False   54527         3          right
# 3  2023090700      101              False   54527         4          right
# 4  2023090700      101              False   54527         5          right
#
#    absolute_yardline_number player_name player_height  player_weight  ...  \
# 0                        42  Bryan Cook           6-1            210  ...
# 1                        42  Bryan Cook           6-1            210  ...
# 2                        42  Bryan Cook           6-1            210  ...
# 3                        42  Bryan Cook           6-1            210  ...
# 4                        42  Bryan Cook           6-1            210  ...
#
#           player_role      x      y     s     a     dir       o  \
# ...

# %% [markdown]
# # Plotting basic player movements

# %%
#From the entire dataset,I am picking out only the rows that belong to the first game and the first play.
one_play = track[
    (track["game_id"] == track["game_id"].iloc[0]) &
    (track["play_id"] == track["play_id"].iloc[0])
]

# %%
plt.figure(figsize=(10, 5))
plt.scatter(one_play["x"], one_play["y"], s=10)
plt.xlabel("X position (yards)")
plt.ylabel("Y position (yards)")
plt.title("Player positions for one play")
plt.show()

# %% [markdown]
# # Tracking only one player

# %%
player_id = one_play["nfl_id"].iloc[0]
# Here I used the very first player
player_track = one_play[one_play["nfl_id"] == player_id]

# %%
plt.figure(figsize=(10, 5))
plt.plot(player_track["x"], player_track["y"], marker="o")
plt.title("Movement of one player during a play")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
player_id = one_play["nfl_id"].unique()[4]
# Here I used the fifth player
player_track = one_play[one_play["nfl_id"] == player_id]

# %%
plt.figure(figsize=(10, 5))
plt.plot(player_track["x"], player_track["y"], marker="o")
plt.title("Movement of one player during a play")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
